# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table
import os
from astropy.io import fits

# %matplotlib inline

# %%
data_path = "/global/project/projectdirs/desi/spectro/data/20191112/"

# %% [markdown]
# Moonlight flat
#
# 22:09 Started GFA sequence for “moon sky test” sequence=GFA, flavor=science, exptime=60.0, count=5, program="moon sky test". Exposures 27337-27342
#
# 22:09 300s moonlight flat, 10 degree from the moon (expid **27339**)

# %%
expid = 27339
filename = os.path.join(data_path, '{:08}'.format(expid), 'desi-{:08d}.fits.fz'.format(expid))

# %%
hduname = 'R4'
data = fits.getdata(filename, hduname)
print(np.median(data), np.max(data), np.min(data))
plt.imshow(np.log10(data-np.min(data)+1))
# Out:
# 2014.0 65535 1779

# %%
hduname = 'Z4'
data = fits.getdata(filename, hduname)
print(np.median(data), np.max(data), np.min(data))
plt.imshow(np.log10(data-np.min(data)+1))
# Out:
# 1999.0 58255 1963

# %% [markdown]
# 22:17 300s moonlight flat, 15 degree from the moon (expid 27345)

# %%
expid = 27345
filename = os.path.join(data_path, '{:08}'.format(expid), 'desi-{:08d}.fits.fz'.format(expid))
data = fits.getdata(filename, hduname)
print(np.median(data), np.max(data), np.min(data))
plt.imshow(np.log10(data-np.min(data)+1))
# Out:
# 2040.0 63389 1964

# %% [markdown]
# 22:23 300s moonlight flat, 20 degree from the moon (expid 27351)

# %%
expid = 27351
filename = os.path.join(data_path, '{:08}'.format(expid), 'desi-{:08d}.fits.fz'.format(expid))
data = fits.getdata(filename, hduname)
print(np.median(data), np.max(data), np.min(data))
plt.imshow(np.log10(data-np.min(data)+1))
# Out:
# 2030.0 62029 1960

# %% [markdown]
# 22:44 300s moonlight flat, 35 degree from the moon (expid 27370)

# %%
expid = 27370
filename = os.path.join(data_path, '{:08}'.format(expid), 'desi-{:08d}.fits.fz'.format(expid))
data = fits.getdata(filename, hduname)
print(np.median(data), np.max(data), np.min(data))
plt.imshow(np.log10(data-np.min(data)+1))
# Out:
# 1999.0 58255 1963

# %% [markdown]
# 23:37 600s exposure for tile 78000 (M31), (expid 27401)

# %%
expid = 27401
hduname = 'R1'
filename = os.path.join(data_path, '{:08}'.format(expid), 'desi-{:08d}.fits.fz'.format(expid))
data = fits.getdata(filename, hduname)
print(np.median(data), np.max(data), np.min(data))
plt.imshow(np.log10(data-np.min(data)+1))
# Out:
# 1992.0 32709 1960

# %%
# main script to process a desi exposure: desi_proc
# https://github.com/desihub/desispec/blob/master/bin/desi_proc
# Out:
# /global/common/software/desi/cori/desiconda/20190804-1.3.0-spec/code/desispec/master/bin/desi_proc
